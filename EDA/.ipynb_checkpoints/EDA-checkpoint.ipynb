# %%
import pandas as pd
import numpy as np
import textblob as tb
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ## Generating a Wordcloud image of all the review texts

# %%
data_path = "C:/Users/Home/Desktop/github projects/xdi-amazon-eda-ml/Data"
df = pd.read_csv(data_path + "/Reviews.csv")
df = df.set_index("Id")

# %%
columns = list(df.columns)
# print(columns)
users = list(df["UserId"].unique()) # 25k+ users
df.head()
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 1                      1                       1      5  1303862400
# 2                      0                       0      1  1346976000
# 3                      1                       1      4  1219017600
# 4                      3                       3      2  1307923200
# 5                      0                       0      5  1350777600
#
#                   Summary                                               Text
# Id
# 1   Good Quality Dog Food  I have bought several of the Vitality canned d...
# 2       Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 3   "Delight" says it all  This is a confection that has been around a fe...
# 4          Cough Medicine  If you are looking for the secret ingredient i...
# 5             Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Creating a WordCloud image of the first 30,000 reviews

# %%
wordcloud_df = df["Text"]
words_dict = {}
for i in range(1, 30_000):
    curr_sent = wordcloud_df[i].split()
    for word in curr_sent:
        if word in words_dict:
            words_dict[word] += 1
        else:
            words_dict[word] = 1

# %%
from wordcloud import STOPWORDS
import string
# not_needed = string.puntuation
cloud = WordCloud(background_color='white', stopwords = STOPWORDS)
cloud.generate_from_frequencies(words_dict)
img = cloud.to_array()
plt.figure(figsize=(8,8))
plt.imshow(img, interpolation = 'nearest')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Analysing reviewer's rating as per helpful votes

# %%
df.head()
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 1                      1                       1      5  1303862400
# 2                      0                       0      1  1346976000
# 3                      1                       1      4  1219017600
# 4                      3                       3      2  1307923200
# 5                      0                       0      5  1350777600
#
#                   Summary                                               Text
# Id
# 1   Good Quality Dog Food  I have bought several of the Vitality canned d...
# 2       Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 3   "Delight" says it all  This is a confection that has been around a fe...
# 4          Cough Medicine  If you are looking for the secret ingredient i...
# 5             Great taffy  Great taffy at a great price.  There was a wid...

# %%
# Testing other way of sentiment analysis
sent_df = df[["UserId", "Text"]].head(30_000)

for i in range(1, 30_001):
    user, text = sent_df.loc[i]
    # Cleaning the text here.

# %% [markdown]
# ## Sentiment Analysis

# %%
# taking a lot of time for the dataset.

from nltk.sentiment.vader import SentimentIntensityAnalyzer
users_sentiment = {}

def calc_sentiment():
    user_text_df = df[["UserId", "Summary", "ProfileName"]]
    for index, row in user_text_df.iterrows():
#         print(index)
        userID, review, name = list(row)
#         print(review)
        score = SentimentIntensityAnalyzer().polarity_scores(review)
#         print(score)
        if userID in users_sentiment.keys():
            users_sentiment[userID]['negative'] += score['neg']
            users_sentiment[userID]['neutral'] += score['neu']
            users_sentiment[userID]['positive'] += score['pos']
            users_sentiment[userID]['times'] += 1
        else:
#             print(score['neg'])
            users_sentiment[userID] = {
                'negative' : score['neg'],
                'neutral' : score['neu'],
                'positive' : score['pos'],
                'times' : 1,
                "name" : name
            }

#         print(users_sentiment.keys())
#         break
    print(users_sentiment)
        
calc_sentiment()
